# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import tensorflow as tf 
import torch

# %%
df = pd.read_csv('../DATA/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data = df , hue = "species")

# %%
species_one_hot = pd.get_dummies(df["species"] )  
species_one_hot
# Out:
#      setosa  versicolor  virginica
# 0      True       False      False
# 1      True       False      False
# 2      True       False      False
# 3      True       False      False
# 4      True       False      False
# ..      ...         ...        ...
# 145   False       False       True
# 146   False       False       True
# 147   False       False       True
# 148   False       False       True
# 149   False       False       True
#
# [150 rows x 3 columns]

# %%
df = df.drop("species" , axis = 1)

# %%
df = pd.concat([df , species_one_hot] , axis = 1 )

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  setosa  versicolor  \
# 0             5.1          3.5           1.4          0.2    True       False
# 1             4.9          3.0           1.4          0.2    True       False
# 2             4.7          3.2           1.3          0.2    True       False
# 3             4.6          3.1           1.5          0.2    True       False
# 4             5.0          3.6           1.4          0.2    True       False
# ..            ...          ...           ...          ...     ...         ...
# 145           6.7          3.0           5.2          2.3   False       False
# 146           6.3          2.5           5.0          1.9   False       False
# 147           6.5          3.0           5.2          2.0   False       False
# 148           6.2          3.4           5.4          2.3   False       False
# 149           5.9          3.0           5.1          1.8   False       False
#
#      virginica
# 0        False
# ...

# %%
# converting dataframe to numpy array using .values 
X = df.drop(["setosa", "versicolor" , "virginica"] , axis = 1).values

# %%
# converting dataframe to numpy array using .values 
y = df[["setosa", "versicolor" , "virginica"]].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150, 3)

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
y
# Out:
# array([[ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
# ...

# %%
dtype = torch.get_default_dtype()

# %%
dtype
# Out:
# torch.float32

# %%
from kan import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

dataset = {}

train_input = X_train
test_input = X_test
train_label = y_train
test_label = y_test

# Ensure labels have the correct shape
train_input = train_input.reshape(train_input.shape[0], -1)
test_input = test_input.reshape(test_input.shape[0], -1)     
train_label = train_label.reshape(train_label.shape[0] , -1)     
test_label = test_label.reshape(test_label.shape[0] , -1)                          

dtype = torch.get_default_dtype()

dataset['train_input'] = torch.from_numpy(train_input).type(dtype).to(device)
dataset['test_input'] = torch.from_numpy(test_input).type(dtype).to(device)
dataset['train_label'] = torch.from_numpy(train_label).type(dtype).to(device)
dataset['test_label'] = torch.from_numpy(test_label).type(dtype).to(device)   

X = dataset['train_input']
y = dataset['train_label']
plt.scatter(X[:,0].cpu().detach().numpy(), X[:,1].cpu().detach().numpy(), c=y[:].cpu().detach().numpy())
# Out:
# cpu

# %%
plt.scatter(X[:,0].cpu().detach().numpy(), X[:,2].cpu().detach().numpy(), c=y[:].cpu().detach().numpy())

# %%
plt.scatter(X[:,0].cpu().detach().numpy(), X[:,3].cpu().detach().numpy(), c=y[:].cpu().detach().numpy())

# %%
plt.scatter(X[:,1].cpu().detach().numpy(), X[:,0].cpu().detach().numpy(), c=y[:].cpu().detach().numpy())

# %%
plt.scatter(X[:,1].cpu().detach().numpy(), X[:,2].cpu().detach().numpy(), c=y[:].cpu().detach().numpy())

# %%
train_input.shape
# Out:
# (105, 4)

# %%
train_label.shape
# Out:
# (105, 3)

# %%
dataset["train_input"].shape
# Out:
# torch.Size([105, 4])

# %%
dataset["train_label"].shape
# Out:
# torch.Size([105, 3])

# %%
dataset["test_input"].shape
# Out:
# torch.Size([45, 4])

# %%
dataset["test_label"].shape
# Out:
# torch.Size([45, 3])

# %%
model = KAN(width=[4   ,  3], grid=6, k=3, seed=2024, device=device)  

#def train_acc():
    #return torch.mean((torch.argmax(model(dataset['train_input']), dim=1) == dataset['train_label']).type(dtype))   

def train_acc():
    return torch.mean((torch.argmax(model(dataset['train_input']), dim=1) == torch.argmax(dataset['train_label'], dim=1)).float())


#def test_acc():                           
    #return torch.mean((torch.argmax(model(dataset['test_input']), dim=1) == dataset['test_label']).type(dtype))

def test_acc():
    return torch.mean((torch.argmax(model(dataset['test_input']), dim=1) == torch.argmax(dataset['test_label'], dim=1)).float())


results = model.fit(dataset, opt="LBFGS", steps=20, metrics=(train_acc, test_acc), loss_fn = torch.nn.BCEWithLogitsLoss());
# Out:
# checkpoint directory created: ./model
# saving model version 0.0
# description:   0%|                                                           | 0/20 [00:00<?, ?it/s]
# | train_loss: 8.01e-06 | test_loss: 9.51e-01 | reg: 2.08e+03 | : 100%|█| 20/20 [00:01<00:00, 19.28it
# saving model version 0.1

# %%
lib = ['x','x^2','x^3','x^4','exp','log','sqrt','tanh','sin','abs']
model.auto_symbolic(lib=lib)
# Out:
# fixing (0,0,0) with x, r2=0.9959931969642639, c=1
# fixing (0,0,1) with x, r2=0.10486110299825668, c=1
# fixing (0,0,2) with x, r2=0.5077663660049438, c=1
# fixing (0,1,0) with x, r2=0.9920413494110107, c=1
# fixing (0,1,1) with x, r2=0.12792839109897614, c=1
# fixing (0,1,2) with x, r2=0.41109880805015564, c=1
# fixing (0,2,0) with x, r2=0.9987246990203857, c=1
# fixing (0,2,1) with sin, r2=0.9725738167762756, c=2
# fixing (0,2,2) with x, r2=0.9579593539237976, c=1
# fixing (0,3,0) with x, r2=0.9866369366645813, c=1
# fixing (0,3,1) with sin, r2=0.9893336296081543, c=2
# fixing (0,3,2) with x, r2=0.7183497548103333, c=1
# saving model version 0.2

# %%
formula1, formula2 ,formula3  = model.symbolic_formula()[0]
ex_round(formula1, 4)
# Out:
# 8.841*x_1 + 38.4788*x_2 - 64.6654*x_3 - 26.8691*x_4 + 27.9878

# %%
model.symbolic_formula()
# Out:
# ([8.84101985639427*x_1 + 38.4787902832031*x_2 - 64.6654168873629*x_3 - 26.8691444396973*x_4 + 27.9878293050335,
#   84.0722684736515*x_1 + 165.648349936655*x_2 - 500.591278076172*sin(1.14799988269806*x_3 + 6.80000019073486) - 729.459655761719*sin(2.79967999458313*x_4 + 7.80919981002808) - 1050.45514915993,
#   -49.9707227796262*x_1 - 77.5798193841779*x_2 + 83.107967866581*x_3 + 143.91603183047*x_4 - 32.6559817646066],
#  [x_1, x_2, x_3, x_4])

# %%
model.symbolic_formula()[0]
# Out:
# [8.84101985639427*x_1 + 38.4787902832031*x_2 - 64.6654168873629*x_3 - 26.8691444396973*x_4 + 27.9878293050335,
#  84.0722684736515*x_1 + 165.648349936655*x_2 - 500.591278076172*sin(1.14799988269806*x_3 + 6.80000019073486) - 729.459655761719*sin(2.79967999458313*x_4 + 7.80919981002808) - 1050.45514915993,
#  -49.9707227796262*x_1 - 77.5798193841779*x_2 + 83.107967866581*x_3 + 143.91603183047*x_4 - 32.6559817646066]

# %%
ex_round(formula1, 4)
# Out:
# 8.841*x_1 + 38.4788*x_2 - 64.6654*x_3 - 26.8691*x_4 + 27.9878

# %%
# How accurate is this formula ? 
def acc(formula1 , formula2, formula3 , X, y):
    batch = X.shape[0]
    correct = 0
    for i in range(batch):
        # Substitute the values and evaluate numerically
        logit1 = float(formula1.subs({'x_1': X[i, 0], 'x_2': X[i, 1]}).evalf())
        logit2 = float(formula2.subs({'x_1': X[i, 0], 'x_2': X[i, 1]}).evalf())
        logit3 = float(formula3.subs({'x_1': X[i, 0], 'x_2': X[i, 1]}).evalf()) 
        
        # Compare predictions
        correct += (logit2 > logit1) == y[i]
    return correct / batch

# Test the function
print('train acc of the formula:', acc(formula1, formula2, formula3 , dataset['train_input'], dataset['train_label']))
print('test acc of the formula:', acc(formula1, formula2, formula3 , dataset['test_input'], dataset['test_label']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 16
#      13     return correct / batch
#      15 # Test the function
# ---> 16 print('train acc of the formula:', acc(formula1, formula2, formula3 , dataset['train_input'], dataset['train_label']))
#      17 print('test acc of the formula:', acc(formula1, formula2, formula3 , dataset['test_input'], dataset['test_label']))
#
# Cell In[41], line 7, in acc(formula1, formula2, formula3, X, y)
#       4 correct = 0
#       5 for i in range(batch):
#       6     # Substitute the values and evaluate numerically
# ----> 7     logit1 = float(formula1.subs({'x_1': X[i, 0], 'x_2': X[i, 1]}).evalf())
#       8     logit2 = float(formula2.subs({'x_1': X[i, 0], 'x_2': X[i, 1]}).evalf())
#       9     logit3 = float(formula3.subs({'x_1': X[i, 0], 'x_2': X[i, 1]}).evalf())
#
# ...

# %%
def acc(formula1, formula2, X, y):
    batch = X.shape[0]
    correct = 0
    for i in range(batch):
        # Substitute the values into the formulas
        logit1_sym = formula1.subs({'x_1': X[i, 0], 'x_2': X[i, 1]})
        logit2_sym = formula2.subs({'x_1': X[i, 0], 'x_2': X[i, 1]})
        
        # Debugging: Print intermediate results
        print(f"Substituted logit1: {logit1_sym}")
        print(f"Substituted logit2: {logit2_sym}")
        
        # Evaluate the symbolic expressions numerically
        logit1 = float(logit1_sym.evalf())
        logit2 = float(logit2_sym.evalf())
        
        # Compare predictions
        correct += (logit2 > logit1) == y[i]
    return correct / batch

# Test the function
print('train acc of the formula:', acc(formula1, formula2, dataset['train_input'], dataset['train_label']))
print('test acc of the formula:', acc(formula1, formula2, dataset['test_input'], dataset['test_label']))
# Out:
# Substituted logit1: -352.696896530116*x_3 - 41.1228999907748*(0.241143311163797 - x_4)**2 - 6.72956386832506*(1 - 0.0860884100095499*x_3)**2 - 0.364786497738298*exp(2.91423964500427*x_4) + 5.73293511195795*log(4.31999969482422 - 0.984000027179718*x_4) - 3.47687609532017*log(6.75375986099243 - 2.18535995483398*x_4) - 0.00307208130661307*sin(0.637839913368225*x_4 + 1.97456002235413) - 3.62247277315566*sin(0.701360046863556*x_4 - 1.45647954940796) - 130.131881150293*sin(1.13719987869263*x_4 - 7.72696018218994) - 2.09180440689582*sin(1.38663959503174*x_4 - 1.38799965381622) - 0.091734990477562*sin(0.302460843957775*x_3 + 0.0178955842836463*(-x_4 - 0.969055460032264)**2 + 11.9689524967795) + 412.898895036307
# ...

# %%
def acc(formula1, formula2, formula3 , X, y):
    batch = X.shape[0]
    correct = 0
    for i in range(batch):
        # Create a substitution dictionary dynamically
        subs_dict = {f'x_{j+1}': X[i, j] for j in range(X.shape[1])}
        
        # Substitute the values into the formulas
        logit1_sym = formula1.subs(subs_dict)
        logit2_sym = formula2.subs(subs_dict)
        logit3_sym = formula3.subs(subs_dict) 
        
        # Debugging: Print intermediate results
        #print(f"Substitution Dictionary: {subs_dict}")
        #print(f"Substituted logit1: {logit1_sym}")
        #print(f"Substituted logit2: {logit2_sym}")
        #print(f"Substituted logit3: {logit3_sym}")  
        
        # Evaluate the symbolic expressions numerically
        logit1 = float(logit1_sym.evalf())
        logit2 = float(logit2_sym.evalf())
        logit3 = float(logit3_sym.evalf()) 
        
        # Determine the predicted class based on the maximum logit
        predicted_class = max((logit1, 0), (logit2, 1), (logit3, 2), key=lambda x: x[0])[1]
        
        # Compare predictions with actual labels
        correct += (predicted_class == y[i]) 
        

    return correct / batch

# Test the function 
print('train acc of the formula:', acc(formula1, formula2, formula3 ,dataset['train_input'], dataset['train_label']))
print('test acc of the formula:', acc(formula1, formula2, formula3 , dataset['test_input'], dataset['test_label']))
# Out:
# train acc of the formula: tensor([0.0000, 0.6190, 0.3143])
# test acc of the formula: tensor([0.0000, 0.7111, 0.4222])

# %%
# how accurate is this formula?
def acc(formula1, formula2, X, y):
    batch = X.shape[0]
    correct = 0
    for i in range(batch):
        logit1 = np.array(formula1.subs('x_1', X[i,0]).subs('x_2', X[i,1])).astype(np.float32)
        logit2 = np.array(formula2.subs('x_1', X[i,0]).subs('x_2', X[i,1])).astype(np.float32)
        correct += (logit2 > logit1) == y[i]
    return correct/batch

print('train acc of the formula:', acc(formula1, formula2, dataset['train_input'], dataset['train_label']))
print('test acc of the formula:', acc(formula1, formula2, dataset['test_input'], dataset['test_label']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 11
#       8         correct += (logit2 > logit1) == y[i]
#       9     return correct/batch
# ---> 11 print('train acc of the formula:', acc(formula1, formula2, dataset['train_input'], dataset['train_label']))
#      12 print('test acc of the formula:', acc(formula1, formula2, dataset['test_input'], dataset['test_label']))
#
# Cell In[149], line 6, in acc(formula1, formula2, X, y)
#       4 correct = 0
#       5 for i in range(batch):
# ----> 6     logit1 = np.array(formula1.subs('x_1', X[i,0]).subs('x_2', X[i,1])).astype(np.float32)
#       7     logit2 = np.array(formula2.subs('x_1', X[i,0]).subs('x_2', X[i,1])).astype(np.float32)
#       8     correct += (logit2 > logit1) == y[i]
#
# File c:\Users\gaurav\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\core\expr.py:340, in Expr.__float__(self)
# ...
